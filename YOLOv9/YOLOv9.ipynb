# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
ROOT_DIR = "/content/drive/MyDrive/drones"

# %%
# !wget -P {ROOT_DIR}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-c.pt
# !wget -P {ROOT_DIR}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-e.pt
# !wget -P {ROOT_DIR}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-c.pt
# !wget -P {ROOT_DIR}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-e.pt

# %%
# !git clone https://github.com/SkalskiP/yolov9.git
# %cd yolov9
# Out:
# Cloning into 'yolov9'...
# remote: Enumerating objects: 147, done.
# remote: Total 147 (delta 0), reused 0 (delta 0), pack-reused 147
# Receiving objects: 100% (147/147), 607.53 KiB | 10.13 MiB/s, done.
# Resolving deltas: 100% (58/58), done.
# /content/drive/MyDrive/yolov9

# %%
import os
files = os.listdir(ROOT_DIR)
files
# Out:
# ['google_colab.yaml',
#  'data',
#  'detector_1.ipynb',
#  'weights',
#  'yolov9',
#  '.ipynb_checkpoints',
#  'drone.mp4']

# %%
# !pip install ultralytics

# %%
# %cd {ROOT_DIR}/yolov9

# !python train.py \
--batch 16 --epochs 20 --img 640 --device 0 --min-items 0 --close-mosaic 15 \
--data "/content/drive/MyDrive/drones/google_colab.yaml" \
--weights {ROOT_DIR}/weights/gelan-c.pt \
--cfg models/detect/gelan-c.yaml \
--hyp hyp.scratch-high.yaml

# %%
# !python detect.py --img 1280 --conf 0.1 --device 0 --weights "/content/drive/MyDrive/drones/yolov9/runs/train/exp/weights/best.pt" --source "/content/drive/MyDrive/drones/drone.mp4"
# Out:
# detect: weights=['/content/drive/MyDrive/drones/yolov9/runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/drones/drone.mp4, data=data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: YOLO requirements "gitpython" "ipython" not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 10.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 60.3 MB/s eta 0:00:00
# ...
#
# requirements: 2 packages updated per /content/drive/MyDrive/yolov9/requirements.txt
# ...
